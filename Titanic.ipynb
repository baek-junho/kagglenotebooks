# %% [markdown]
# ###### 참조 : https://www.kaggle.com/ash316/eda-to-prediction-dietanic

# %% [markdown]
# # Part1: Exploratory Data Analysis(EDA)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('../타이타닉 data/train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## How many Survived??

# %%
f,ax = plt.subplots(1,2,figsize = (18,8))
data["Survived"].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%', ax = ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data = data, ax = ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# ## Analysing The Features // Sex--> Categorical Feature

# %%
data.groupby(['Sex', 'Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Sex', 'Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex', hue='Survived', data = data, ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %% [markdown]
# ## Pclass -> Ordinal Feature

# %%
pd.crosstab(data.Pclass, data.Survived, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_aa02fd1a_cd65_11ea_8a01_7cb27d01128crow0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_aa02fd1a_cd65_11ea_8a01_7cb27d01128crow0_col1 {
#             background-color:  #cee666;
#             color:  #000000;
#         }    #T_aa02fd1a_cd65_11ea_8a01_7cb27d01128crow0_col2 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_aa02fd1a_cd65_11ea_8a01_7cb27d01128crow1_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_aa02fd1a_cd65_11ea_8a01_7cb27d01128crow1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_aa02fd1a_cd65_11ea_8a01_7cb27d01128crow1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_aa02fd1a_cd65_11ea_8a01_7cb27d01128crow2_col0 {
#             background-color:  #60b066;
#             color:  #000000;
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue = 'Survived', data = data, ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %%
pd.crosstab([data.Sex, data.Survived], data.Pclass, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_aa71f170_cd65_11ea_bfe9_7cb27d01128crow0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_aa71f170_cd65_11ea_bfe9_7cb27d01128crow0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_aa71f170_cd65_11ea_bfe9_7cb27d01128crow0_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_aa71f170_cd65_11ea_bfe9_7cb27d01128crow0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_aa71f170_cd65_11ea_bfe9_7cb27d01128crow1_col0 {
#             background-color:  #96cb66;
#             color:  #000000;
#         }    #T_aa71f170_cd65_11ea_bfe9_7cb27d01128crow1_col1 {
#             background-color:  #a3d166;
#             color:  #000000;
#         }    #T_aa71f170_cd65_11ea_bfe9_7cb27d01128crow1_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
# ...

# %%
sns.factorplot('Pclass', 'Survived', hue = 'Sex', data=data)
plt.show()

# %% [markdown]
# #### 남성보다 여성의 생존율이 높다 구출우선순위가 부여된것 같다

# %% [markdown]
# ## Age--> Continous Feature

# %%
print('Oldeset Passenger was of:', data['Age'].max(),'Years')
print('Youngest Passenger was of:', data['Age'].min(),'Years')
print('Average Age on the ship:', data['Age'].mean(),'Years')
# Out:
# Oldeset Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass", "Age", hue="Survived", data=data,split=True, ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True, ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
# #### 어린이수(10세미만)는 클래스에따라 증가하고 생존율은 클래스와 상관없이 양호하다

# %% [markdown]
# #### 20~50세의 승객이 생존가능성이 높고 그중에서 여성이 더 높다

# %% [markdown]
# #### 남성의 경우 생존 확률은 나이가 증가함에 따라 감소한다

# %% [markdown]
# #### 하지만 Age 컬럼에 177개의 null 값이 존재하고 나이가 다른 사람들이 많다 그래서 이름 기능을 활용하여 Mr, Mrs 평균값을 각 그룹에 할당한다

# %%
data['Initial']=0
for i in data:
    data['Initial']=data.Name.str.extract('([A-Za-z]+)\.')

# %%
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_ab8ef56e_cd65_11ea_b343_7cb27d01128crow0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ab8ef56e_cd65_11ea_b343_7cb27d01128crow0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ab8ef56e_cd65_11ea_b343_7cb27d01128crow0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_ab8ef56e_cd65_11ea_b343_7cb27d01128crow0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ab8ef56e_cd65_11ea_b343_7cb27d01128crow0_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ab8ef56e_cd65_11ea_b343_7cb27d01128crow0_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ab8ef56e_cd65_11ea_b343_7cb27d01128crow0_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# #### Mlle이나 Mme과 같이 맞춤법이 틀린 이니셜이 Miss를 뜻하는 것이므로 다른 값으로 대체한다

# %%
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %% [markdown]
# ### NaN Age 값 채우기

# %%
#위에서 구한 평균으로 넣기
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

# %%
data.Age.isnull().any()
# Out:
# False

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %%
sns.factorplot('Pclass', 'Survived', col = 'Initial', data= data)
plt.show()

# %% [markdown]
# #### 여성과 아동의 경우 클래스와 상관없이 먼저였다????????????(로 해석하는게 맞나)

# %% [markdown]
# ## Embarked--> Categorical Value

# %%
pd.crosstab([data.Embarked, data.Pclass], [data.Sex, data.Survived],
            margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_ad6a9b76_cd65_11ea_9cad_7cb27d01128crow0_col0 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_ad6a9b76_cd65_11ea_9cad_7cb27d01128crow0_col1 {
#             background-color:  #d2e866;
#             color:  #000000;
#         }    #T_ad6a9b76_cd65_11ea_9cad_7cb27d01128crow0_col2 {
#             background-color:  #f2f866;
#             color:  #000000;
#         }    #T_ad6a9b76_cd65_11ea_9cad_7cb27d01128crow0_col3 {
#             background-color:  #d8ec66;
#             color:  #000000;
#         }    #T_ad6a9b76_cd65_11ea_9cad_7cb27d01128crow0_col4 {
#             background-color:  #e8f466;
#             color:  #000000;
#         }    #T_ad6a9b76_cd65_11ea_9cad_7cb27d01128crow1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ad6a9b76_cd65_11ea_9cad_7cb27d01128crow1_col1 {
#             background-color:  #f9fc66;
#             color:  #000000;
# ...

# %%
sns.factorplot('Embarked','Survived',data=data)
fig=plt.gcf()
fig.set_size_inches(5,3)
plt.show()

# %% [markdown]
# #### C가 생존률이 가장 높고 S가 가장낮다

# %%
f,ax=plt.subplots(2,2,figsize=(20,15))
sns.countplot('Embarked',data=data,ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')
sns.countplot('Embarked',hue='Sex',data=data,ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot('Embarked',hue='Survived',data=data,ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('Embarked',hue='Pclass',data=data,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %%
sns.factorplot('Pclass', 'Survived', hue = 'Sex', col='Embarked', data=data)
plt.show()

# %%
data['Embarked'].fillna('S',inplace=True)

# %%
data.Embarked.isnull().any()
# Out:
# False

# %% [markdown]
# ## SibSip-->Discrete Feature

# %% [markdown]
# ### 사람이 혼자인지 가족과 함께있는지 확인

# %%
pd.crosstab([data.SibSp],data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_af7e6524_cd65_11ea_a791_7cb27d01128crow0_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_af7e6524_cd65_11ea_a791_7cb27d01128crow0_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_af7e6524_cd65_11ea_a791_7cb27d01128crow1_col0 {
#             background-color:  #c4e266;
#             color:  #000000;
#         }    #T_af7e6524_cd65_11ea_a791_7cb27d01128crow1_col1 {
#             background-color:  #77bb66;
#             color:  #000000;
#         }    #T_af7e6524_cd65_11ea_a791_7cb27d01128crow2_col0 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_af7e6524_cd65_11ea_a791_7cb27d01128crow2_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_af7e6524_cd65_11ea_a791_7cb27d01128crow3_col0 {
#             background-color:  #fbfd66;
#             color:  #000000;
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('SibSp','Survived',data=data,ax=ax[0])
ax[0].set_title('SibSp vs Survived')
sns.factorplot('SibSp','Survived',data=data,ax=ax[1])
ax[1].set_title('SibSp vs Survived')
plt.show()
# 맨윗줄 (1,2 하면 두번째 차트 사라져야하는데 안됨)

# %%
pd.crosstab(data.SibSp,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_b0774d88_cd65_11ea_b5c0_7cb27d01128crow0_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b0774d88_cd65_11ea_b5c0_7cb27d01128crow0_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b0774d88_cd65_11ea_b5c0_7cb27d01128crow0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b0774d88_cd65_11ea_b5c0_7cb27d01128crow1_col0 {
#             background-color:  #7bbd66;
#             color:  #000000;
#         }    #T_b0774d88_cd65_11ea_b5c0_7cb27d01128crow1_col1 {
#             background-color:  #8ac466;
#             color:  #000000;
#         }    #T_b0774d88_cd65_11ea_b5c0_7cb27d01128crow1_col2 {
#             background-color:  #c6e266;
#             color:  #000000;
#         }    #T_b0774d88_cd65_11ea_b5c0_7cb27d01128crow2_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
# ...

# %% [markdown]
# #### 그래프를 보면 승객중에 형제 자매 없이 혼자 탑승하는 경우 생존률이 34.5%이고 형제 수가 증가 하면 그래프가 감소하는 것을 확인할수가 있다. 즉 가족이 있으면 내가 먼저가 아니고 가족을 먼저 구하려고 노력할 것이기 때문이다. 그리고 크로스 탭은 SibSp>3인 대가족인 경우 3클래스에  있음을 보여주고, 모든 대가족이 죽었다는 것을 볼수있다.

# %% [markdown]
# ##  Parch

# %%
pd.crosstab(data.Parch, data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_b07fd99e_cd65_11ea_b960_7cb27d01128crow0_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b07fd99e_cd65_11ea_b960_7cb27d01128crow0_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b07fd99e_cd65_11ea_b960_7cb27d01128crow0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_b07fd99e_cd65_11ea_b960_7cb27d01128crow1_col0 {
#             background-color:  #cfe766;
#             color:  #000000;
#         }    #T_b07fd99e_cd65_11ea_b960_7cb27d01128crow1_col1 {
#             background-color:  #c2e066;
#             color:  #000000;
#         }    #T_b07fd99e_cd65_11ea_b960_7cb27d01128crow1_col2 {
#             background-color:  #dbed66;
#             color:  #000000;
#         }    #T_b07fd99e_cd65_11ea_b960_7cb27d01128crow2_col0 {
#             background-color:  #dfef66;
#             color:  #000000;
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('Parch','Survived',data=data,ax=ax[0])
ax[0].set_title('Parch vs Survived')
sns.factorplot('Parch','Survived',data=data,ax=ax[1])
ax[1].set_title('Parch vs Survived')
plt.show()

# %% [markdown]
# ####  여기에서도 결과는 비슷하다

# %% [markdown]
# ## Fare--> Continous Feature

# %%
print('Highest Fare was:', data['Fare'].max())
print('Lowest Fare was:', data['Fare'].min())
print('Average Fare was:', data['Fare'].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was: 0.0
# Average Fare was: 32.2042079685746

# %%
f,ax=plt.subplots(1,3,figsize=(20,8))
sns.distplot(data[data['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')
sns.distplot(data[data['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')
sns.distplot(data[data['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()

# %% [markdown]
# ###### 성별컬럼 : 남성보다 여성의 생존확률이 더 높다

# %% [markdown]
# ###### 클래스컬럼 : 상위 클래스일수록 생존 확률이 높다 Pclass3 인 경우 생존 확률이 매우 낮다 > 돈이 짱이다

# %% [markdown]
# ###### 나이컬럼: 5~10세 미만의 어린이는 생존 가능성이 높고 15~35세 승객은 많이 사망했다

# %% [markdown]
# ## Correlation Between The Features

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()->corrleation matrix
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %% [markdown]
# # Part2: Feature Engineering and Data Cleaning

# %% [markdown]
# ###### 데이터를 제거하거나 생성해준다 또한 기존 관련 기능을 예측 모델링에 적합한 형식으로 변환시켜준다

# %% [markdown]
# ### Age_band 생성

# %% [markdown]
# ###### 앞서 언급 한 것처럼 Age는 연속적인 기능이므로 Machine Learning Models에서 연속 변수에 문제가 있습니다.

# %% [markdown]
# ###### 나이별로 그룹지어준듯

# %%
data['Age_band']= 0
data.loc[data['Age']<=16, 'Age_band']=0
data.loc[(data['Age']>16)&(data['Age']<=32),'Age_band']=1
data.loc[(data['Age']>32)&(data['Age']<=48),'Age_band']=2
data.loc[(data['Age']>48)&(data['Age']<=64),'Age_band']=3
data.loc[data['Age']>64, 'Age_band']= 4
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked Initial  Age_band
# 0      0  A/5 21171   7.2500   NaN        S      Mr         1
# 1      0   PC 17599  71.2833   C85        C     Mrs         2

# %%
data['Age_band'].value_counts().to_frame().style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_7bcf70f0_cd85_11ea_b49c_7cb27d01128crow0_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_7bcf70f0_cd85_11ea_b49c_7cb27d01128crow1_col0 {
#             background-color:  #279366;
#             color:  #000000;
#         }    #T_7bcf70f0_cd85_11ea_b49c_7cb27d01128crow2_col0 {
#             background-color:  #bfdf66;
#             color:  #000000;
#         }    #T_7bcf70f0_cd85_11ea_b49c_7cb27d01128crow3_col0 {
#             background-color:  #d7eb66;
#             color:  #000000;
#         }    #T_7bcf70f0_cd85_11ea_b49c_7cb27d01128crow4_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_7bcf70f0_cd85_11ea_b49c_7cb27d01128c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Age_band</th>    </tr></thead><tbody>
#                 <tr>
# ...
